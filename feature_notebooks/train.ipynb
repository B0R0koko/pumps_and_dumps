# %%
from pathlib import Path

import pandas as pd
import os

ROOT_DIR = Path(os.getcwd()).parent

# %%
df = pd.read_parquet(
    os.path.join(ROOT_DIR, "features/data/train.parquet")
)

# %%
df
# Out:
#        long_whale_99_num_trades_ratio_100_H  net_99_slippage_100_H  \
# index
# 0                                  0.032258           8.013860e-04
# 0                                  0.104592           3.639161e-03
# 0                                  0.140845           9.179810e-03
# 0                                  0.000000           3.580469e-15
# 0                                  0.075000          -3.385950e-03
# ...                                     ...                    ...
# 0                                  0.168317          -1.038549e-03
# 0                                  0.115741           1.479902e-02
# 0                                  0.115942          -1.442485e-03
# 0                                  0.133621          -5.989860e-03
# 0                                  0.108247           1.998600e-03
#
#        net_whale_slippage_100_H  quan_99_imbalance_ratio_100_H  \
# index
# 0                     -0.004378                      -0.054830
# ...
